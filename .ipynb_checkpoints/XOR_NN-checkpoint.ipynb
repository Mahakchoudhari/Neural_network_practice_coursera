# %%
import numpy as np

# %%
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

# %%
Y = np.array([[0], [1], [1], [0]])

# %%
X.shape
# Out:
# (4, 2)

# %%
Y.shape
# Out:
# (4, 1)

# %%
#hiiden layer
W1 = np.random.randn(2,2)
b1 = np.zeros((2,1))

#output layer
W2 = np.random.randn(1,2)
b2 = np.zeros((1,1))
