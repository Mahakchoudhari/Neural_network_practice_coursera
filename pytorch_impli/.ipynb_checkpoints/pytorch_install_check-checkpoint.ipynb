# %%
import torch

print(torch.__version__)
print(torch.rand(2,3))
# Out:
# 2.12.0+cpu
# tensor([[0.5776, 0.4674, 0.1108],
#         [0.8384, 0.2695, 0.0978]])

# %%
print(torch.cuda.is_available())
# Out:
# False
